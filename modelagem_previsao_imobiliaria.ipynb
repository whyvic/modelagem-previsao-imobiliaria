# %% [markdown]
# <a href="https://colab.research.google.com/github/whyvic/modelagem-previsao-imobiliaria/blob/main/modelagem_previsao_imobiliaria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df["median_income"], df["median_house_value"], alpha=0.5)
plt.xlabel("Renda Media")
plt.ylabel("Valor Mediano da Casa")
plt.title("Relação entre Renda e Valor das Casas")
plt.show()

# %%
df["faixa_renda"] = pd.cut(df["median_income"], bins=[0, 2, 4, 6, 8, 10, 12, 14])
media_por_faixa = df.groupby("faixa_renda")["median_house_value"].mean()
media_por_faixa.plot(kind="line", marker="o", color="darkgreen", figsize=(8,5))
plt.title("Valor Médio das Casas por Faixa de Renda")
plt.xlabel("Faixa de Renda Mediana")
plt.ylabel("Valor Médio da Casa")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-1994200116.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   media_por_faixa = df.groupby("faixa_renda")["median_house_value"].mean()
